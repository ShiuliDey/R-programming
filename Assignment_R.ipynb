# %% [markdown]
# <a href="https://colab.research.google.com/github/ShiuliDey/R-programming/blob/main/Assignment_R.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **1.Import** the following dataset-
#  https://archive.ics.uci.edu/ml/machine-learning-databases/wine-quality/winequality-red.csv
# [ ]

# %%
install.packages("caret")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘listenv’, ‘parallelly’, ‘future’, ‘globals’, ‘future.apply’, ‘progressr’, ‘numDeriv’, ‘SQUAREM’, ‘lava’, ‘prodlim’, ‘proxy’, ‘iterators’, ‘gower’, ‘ipred’, ‘timeDate’, ‘e1071’, ‘foreach’, ‘ModelMetrics’, ‘plyr’, ‘pROC’, ‘recipes’, ‘reshape2’

# %%
library(caret)
# Out:
# Loading required package: ggplot2
#
# Loading required package: lattice
#
# Warning message in system("timedatectl", intern = TRUE):
# “running command 'timedatectl' had status 1”

# %%
url <-"https://archive.ics.uci.edu/ml/machine-learning-databases/wine-quality/winequality-red.csv"

# %%
download.file(url, "winequality-red.txt")

# %%
d <- read.table("winequality-red.txt", sep = ";" ,header=TRUE)

# %% [markdown]
# 2. Assign appropriate column names.

# %%
colnames(d) <-c("fixed acidity","volatile acidity","citric acid","residual sugar","chlorides","free sulfur dioxide", "total sulfur dioxide","density","pH","sulphates","alcohol","quality")

# %%
d
# Out:
#      fixed acidity volatile acidity citric acid residual sugar chlorides
# 1     7.4          0.700            0.00        1.9            0.076
# 2     7.8          0.880            0.00        2.6            0.098
# 3     7.8          0.760            0.04        2.3            0.092
# 4    11.2          0.280            0.56        1.9            0.075
# 5     7.4          0.700            0.00        1.9            0.076
# 6     7.4          0.660            0.00        1.8            0.075
# 7     7.9          0.600            0.06        1.6            0.069
# 8     7.3          0.650            0.00        1.2            0.065
# 9     7.8          0.580            0.02        2.0            0.073
# 10    7.5          0.500            0.36        6.1            0.071
# 11    6.7          0.580            0.08        1.8            0.097
# 12    7.5          0.500            0.36        6.1            0.071
# 13    5.6          0.615            0.00        1.6            0.089
# ...

# %% [markdown]
# 3. Check for missing values.

# %%
sum(is.na(d))
# Out:
# [1] 0

# %% [markdown]
# 4.Filter the data set based on following conditions: i. Select the columns ( "citric acid", "residual sugar", "density", "pH", "sulphates", "alcohol", "quality")

# %%
d1 <- d[, c("citric acid","residual sugar", "density", "pH", "sulphates","alcohol", "quality")]
d1
# Out:
#      citric acid residual sugar density pH   sulphates alcohol quality
# 1    0.00        1.9            0.9978  3.51 0.56       9.4    5
# 2    0.00        2.6            0.9968  3.20 0.68       9.8    5
# 3    0.04        2.3            0.9970  3.26 0.65       9.8    5
# 4    0.56        1.9            0.9980  3.16 0.58       9.8    6
# 5    0.00        1.9            0.9978  3.51 0.56       9.4    5
# 6    0.00        1.8            0.9978  3.51 0.56       9.4    5
# 7    0.06        1.6            0.9964  3.30 0.46       9.4    5
# 8    0.00        1.2            0.9946  3.39 0.47      10.0    7
# 9    0.02        2.0            0.9968  3.36 0.57       9.5    7
# 10   0.36        6.1            0.9978  3.35 0.80      10.5    5
# 11   0.08        1.8            0.9959  3.28 0.54       9.2    5
# 12   0.36        6.1            0.9978  3.35 0.80      10.5    5
# 13   0.00        1.6            0.9943  3.58 0.52       9.9    5
# ...

# %% [markdown]
# ii. Select only samples where quality>3 and pH>3.

# %%
d2 <- d[(d$quality > 3 & d$pH > "3"), ]
head(d2,10)
# Out:
#    fixed acidity volatile acidity citric acid residual sugar chlorides
# 1   7.4          0.70             0.00        1.9            0.076
# 2   7.8          0.88             0.00        2.6            0.098
# 3   7.8          0.76             0.04        2.3            0.092
# 4  11.2          0.28             0.56        1.9            0.075
# 5   7.4          0.70             0.00        1.9            0.076
# 6   7.4          0.66             0.00        1.8            0.075
# 7   7.9          0.60             0.06        1.6            0.069
# 8   7.3          0.65             0.00        1.2            0.065
# 9   7.8          0.58             0.02        2.0            0.073
# 10  7.5          0.50             0.36        6.1            0.071
#    free sulfur dioxide total sulfur dioxide density pH   sulphates alcohol
# 1  11                   34                  0.9978  3.51 0.56       9.4
# 2  25                   67                  0.9968  3.20 0.68       9.8
# ...

# %% [markdown]
# 5. Sort the data based on quality.

# %%
d3 <-d[order(d$quality), ]
d3
# Out:
#      fixed acidity volatile acidity citric acid residual sugar chlorides
# 460  11.6          0.580            0.66        2.20           0.074
# 518  10.4          0.610            0.49        2.10           0.200
# 691   7.4          1.185            0.00        4.25           0.097
# 833  10.4          0.440            0.42        1.50           0.145
# 900   8.3          1.020            0.02        3.40           0.084
# 1300  7.6          1.580            0.00        2.10           0.137
# 1375  6.8          0.815            0.00        1.20           0.267
# 1470  7.3          0.980            0.05        2.10           0.061
# 1479  7.1          0.875            0.05        5.70           0.082
# 1506  6.7          0.760            0.02        1.80           0.078
# 19    7.4          0.590            0.08        4.40           0.086
# 39    5.7          1.130            0.09        1.50           0.172
# 42    8.8          0.610            0.30        2.80           0.088
# ...

# %% [markdown]
# 6. Obtain the summary of the data.

# %%
summary(d)
# Out:
#  fixed acidity   volatile acidity  citric acid    residual sugar
#  Min.   : 4.60   Min.   :0.1200   Min.   :0.000   Min.   : 0.900
#  1st Qu.: 7.10   1st Qu.:0.3900   1st Qu.:0.090   1st Qu.: 1.900
#  Median : 7.90   Median :0.5200   Median :0.260   Median : 2.200
#  Mean   : 8.32   Mean   :0.5278   Mean   :0.271   Mean   : 2.539
#  3rd Qu.: 9.20   3rd Qu.:0.6400   3rd Qu.:0.420   3rd Qu.: 2.600
#  Max.   :15.90   Max.   :1.5800   Max.   :1.000   Max.   :15.500
#    chlorides       free sulfur dioxide total sulfur dioxide    density
#  Min.   :0.01200   Min.   : 1.00       Min.   :  6.00       Min.   :0.9901
#  1st Qu.:0.07000   1st Qu.: 7.00       1st Qu.: 22.00       1st Qu.:0.9956
#  Median :0.07900   Median :14.00       Median : 38.00       Median :0.9968
#  Mean   :0.08747   Mean   :15.87       Mean   : 46.47       Mean   :0.9967
#  3rd Qu.:0.09000   3rd Qu.:21.00       3rd Qu.: 62.00       3rd Qu.:0.9978
# ...

# %% [markdown]
# 7. Standardize the data set

# %%
# calculate the pre-process parameters from the dataset
preprocessParams <- preProcess(d[,1:11], method=c("center", "scale"))
# summarize transform parameters
print(preprocessParams)
# transform the dataset using the parameters
transformed <- predict(preprocessParams, d[,1:11])
# summarize the transformed dataset
summary(transformed)
# Out:
# Created from 1599 samples and 11 variables
#
# Pre-processing:
#   - centered (11)
#   - ignored (0)
#   - scaled (11)
#  fixed acidity     volatile acidity    citric acid       residual sugar
#  Min.   :-2.1364   Min.   :-2.27757   Min.   :-1.39104   Min.   :-1.1623
#  1st Qu.:-0.7005   1st Qu.:-0.76969   1st Qu.:-0.92903   1st Qu.:-0.4531
#  Median :-0.2410   Median :-0.04367   Median :-0.05634   Median :-0.2403
#  Mean   : 0.0000   Mean   : 0.00000   Mean   : 0.00000   Mean   : 0.0000
#  3rd Qu.: 0.5056   3rd Qu.: 0.62649   3rd Qu.: 0.76501   3rd Qu.: 0.0434
#  Max.   : 4.3538   Max.   : 5.87614   Max.   : 3.74240   Max.   : 9.1928
#    chlorides        free sulfur dioxide total sulfur dioxide    density
#  Min.   :-1.60344   Min.   :-1.4221     Min.   :-1.2302      Min.   :-3.53762
#  1st Qu.:-0.37111   1st Qu.:-0.8485     1st Qu.:-0.7438      1st Qu.:-0.60757
#  Median :-0.17989   Median :-0.1792     Median :-0.2574      Median : 0.00176
# ...

# %% [markdown]
# 8. Perform PCA on the standardized data capturing 80% variance.

# %%
# calculate the pre-process parameters from the dataset
preprocessParams <- preProcess(d, method=c("center", "scale", "pca"),thresh = 0.80)
# summarize transform parameters
print(preprocessParams)
# transform the dataset using the parameters
transformed <- predict(preprocessParams, d)
# summarize the transformed dataset
summary(transformed)
# Out:
# Created from 1599 samples and 12 variables
#
# Pre-processing:
#   - centered (12)
#   - ignored (0)
#   - principal component signal extraction (12)
#   - scaled (12)
#
# PCA needed 6 components to capture 80 percent of the variance
#       PC1               PC2               PC3               PC4
#  Min.   :-5.2011   Min.   :-4.4157   Min.   :-7.5882   Min.   :-10.94928
#  1st Qu.:-1.3005   1st Qu.:-0.9638   1st Qu.:-0.7593   1st Qu.: -0.27569
#  Median :-0.1809   Median : 0.1243   Median : 0.1600   Median :  0.08671
#  Mean   : 0.0000   Mean   : 0.0000   Mean   : 0.0000   Mean   :  0.00000
#  3rd Qu.: 1.0517   3rd Qu.: 0.9970   3rd Qu.: 0.8817   3rd Qu.:  0.46226
#  Max.   : 8.2565   Max.   : 5.1549   Max.   : 3.4557   Max.   :  4.59666
#       PC5                PC6
#  Min.   :-3.49316   Min.   :-2.918439
#  1st Qu.:-0.62306   1st Qu.:-0.544534
#  Median :-0.09358   Median :-0.009437
#  Mean   : 0.00000   Mean   : 0.000000
#  3rd Qu.: 0.41822   3rd Qu.: 0.527294
# ...

# %% [markdown]
# 9. Visualize the data using histogram and box plot.

# %%
cols <- list("fixed acidity","volatile acidity","citric acid","residual sugar","chlorides","free sulfur dioxide", "total sulfur dioxide","density","pH","sulphates","alcohol","quality")

for (x in 1:12) {
  hist(d[,x], main = cols[x])
}
# Out:
# Plot with title “fixed acidity”
# Plot with title “volatile acidity”
# Plot with title “citric acid”
# Plot with title “residual sugar”
# Plot with title “chlorides”
# Plot with title “free sulfur dioxide”
# Plot with title “total sulfur dioxide”
# Plot with title “density”
# Plot with title “pH”
# Plot with title “sulphates”
# Plot with title “alcohol”
# Plot with title “quality”

# %%
library(tidyverse)
# Out:
# Warning message in system("timedatectl", intern = TRUE):
# “running command 'timedatectl' had status 1”
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.1 ──
#
# ✔ ggplot2 3.3.5     ✔ purrr   0.3.4
# ✔ tibble  3.1.6     ✔ dplyr   1.0.7
# ✔ tidyr   1.1.4     ✔ stringr 1.4.0
# ✔ readr   2.1.1     ✔ forcats 0.5.1
#
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()

# %%
url <- "https://archive.ics.uci.edu/ml/machine-learning-databases/wine-quality/winequality-red.csv"

# %%
download.file(url, "wine.txt")
df <- read.table("wine.txt", sep = ";", header = TRUE)
head(df)
breaks <- c(0, 5, 7, 10)
df$quality.category <- cut(df$quality, breaks, include.lowest = TRUE, right = FALSE)
# Out:
#   fixed.acidity volatile.acidity citric.acid residual.sugar chlorides
# 1  7.4          0.70             0.00        1.9            0.076
# 2  7.8          0.88             0.00        2.6            0.098
# 3  7.8          0.76             0.04        2.3            0.092
# 4 11.2          0.28             0.56        1.9            0.075
# 5  7.4          0.70             0.00        1.9            0.076
# 6  7.4          0.66             0.00        1.8            0.075
#   free.sulfur.dioxide total.sulfur.dioxide density pH   sulphates alcohol
# 1 11                  34                   0.9978  3.51 0.56      9.4
# 2 25                  67                   0.9968  3.20 0.68      9.8
# 3 15                  54                   0.9970  3.26 0.65      9.8
# 4 17                  60                   0.9980  3.16 0.58      9.8
# 5 11                  34                   0.9978  3.51 0.56      9.4
# 6 13                  40                   0.9978  3.51 0.56      9.4
#   quality
# ...

# %%
breaks <- c(0, 5, 7, 10)
df$quality.category <- cut(df$quality, breaks, include.lowest = TRUE, right = FALSE)

# %%
ggplot(data = df, aes(x = quality.category, y = volatile.acidity, color =quality.category)) +
  geom_boxplot()
# Out:
# plot without title

# %%
ggplot(data = df, aes(x = quality.category, y = free.sulfur.dioxide, color = quality.category)) +
  geom_boxplot()
# Out:
# plot without title

# %%
ggplot(data = df, aes(x = quality.category, y = fixed.acidity, color = quality.category)) +
  geom_boxplot()
# Out:
# plot without title

# %%
ggplot(data = df, aes(x = quality.category, y = citric.acid, color = quality.category)) +
  geom_boxplot()
# Out:
# plot without title

# %%
ggplot(data = df, aes(x = quality.category, y = residual.sugar, color = quality.category)) +
  geom_boxplot()
# Out:
# plot without title

# %%
ggplot(data = df, aes(x = quality.category, y = chlorides, color = quality.category)) +
  geom_boxplot()
# Out:
# plot without title

# %%
ggplot(data = df, aes(x = quality.category, y = free.sulfur.dioxide, color = quality.category)) +
  geom_boxplot()
# Out:
# plot without title

# %%
ggplot(data = df, aes(x = quality.category, y = total.sulfur.dioxide, color = quality.category)) +
  geom_boxplot()
# Out:
# plot without title

# %%
ggplot(data = df, aes(x = quality.category, y = density, color = quality.category)) +
  geom_boxplot()
# Out:
# plot without title

# %%
ggplot(data = df, aes(x = quality.category, y = pH, color = quality.category)) +
  geom_boxplot()
# Out:
# plot without title

# %%
ggplot(data = df, aes(x = quality.category, y = sulphates, color = quality.category)) +
  geom_boxplot()
# Out:
# plot without title

# %%
ggplot(data = df, aes(x = quality.category, y = alcohol, color = quality.category)) +
  geom_boxplot()
# Out:
# plot without title
